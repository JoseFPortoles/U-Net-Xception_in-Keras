# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseFPortoles/U-Net-Xception_in-Keras/blob/master/u-net-cityscapes_car_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Car segmentation with the Cityscapes dataset
# [Cityscapes](https://www.cityscapes-dataset.com/) [1] is a dataset for semantic understanding of urban scenes. Among other data it contains 5000 color images with their corresponding finely  pixel-wise annotated ground-truth masks. The masks annotate 30 different categories of urban scenery objects including different types of vehicles, people and urban constructions among others.
#
# The following is a simple attempt at training a deep learning model for semantic segmentation of a single category, namely cars, but it is easily adaptable to other categories (by changing the value of a single variable).
#
# The neural architecture employed for this example, a U-Net-Xception style CNN, is adapted from the [keras blog](https://keras.io/examples/vision/oxford_pets_image_segmentation/) [2] with minimal changes.

# %% [markdown]
# ## Set variables

# %%
#Variables
x_imsize = 160
y_imsize = 160
img_size = (x_imsize,y_imsize)
num_classes = 2
batch_size = 32
epochs = 100

# %% [markdown]
# ## Build model

# %%
from tensorflow import keras
from tensorflow.keras import layers

def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model


# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
model = get_model(img_size, num_classes)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 80, 80, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 80, 80, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 80, 80, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 80, 80, 32)   0           activation[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 80, 80, 64)   2400        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 80, 80, 64)   256         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 80, 80, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 80, 80, 64)   4736        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 80, 80, 64)   256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 40, 40, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 40, 40, 64)   2112        activation[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 40, 40, 64)   0           max_pooling2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 40, 40, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 40, 40, 128)  8896        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 40, 40, 128)  512         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 40, 40, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 40, 40, 128)  17664       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 40, 40, 128)  512         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 20, 20, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 20, 20, 128)  8320        add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 20, 20, 128)  0           max_pooling2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 20, 20, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 20, 20, 256)  34176       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 20, 20, 256)  1024        separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 20, 20, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 20, 20, 256)  68096       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 20, 20, 256)  1024        separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 10, 10, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 256)  33024       add_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 10, 10, 256)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 10, 10, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 10, 10, 256)  590080      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 10, 10, 256)  1024        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 10, 10, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 10, 10, 256)  590080      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 10, 10, 256)  1024        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 20, 20, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 20, 20, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 20, 20, 256)  65792       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 20, 20, 256)  0           up_sampling2d[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 20, 20, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 20, 20, 128)  295040      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 20, 20, 128)  512         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 20, 20, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 20, 20, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 20, 20, 128)  512         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 40, 40, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 40, 40, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 40, 40, 128)  32896       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 40, 40, 128)  0           up_sampling2d_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 40, 40, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 40, 40, 64)   73792       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 40, 40, 64)   256         conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 40, 40, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 40, 40, 64)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 40, 40, 64)   256         conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 80, 80, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 80, 80, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 80, 80, 64)   8256        up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 80, 80, 64)   0           up_sampling2d_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 80, 80, 64)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 80, 80, 32)   18464       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 80, 80, 32)   128         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 80, 80, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 80, 80, 32)   9248        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 80, 80, 32)   128         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 160, 160, 64) 0           add_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 160, 160, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 160, 160, 32) 2080        up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 160, 160, 32) 0           up_sampling2d_6[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 160, 160, 2)  578         add_6[0][0]
# ==================================================================================================
# Total params: 2,058,690
# Trainable params: 2,054,914
# Non-trainable params: 3,776
# __________________________________________________________________________________________________

# %% [markdown]
# ## Load a model
# Uncomment and use instead of the model building cell if you want to load a pretrained model.

# %%
#from tensorflow import keras

#model_path ='/content/U-Net-Xception_Segmentation.h5'
#model = keras.models.load_model(model_path)

# %% [markdown]
# ## Gather file paths
# The dataset keeps images and ground thruth masks separated in different folders, each containing subfolders for the training and the validation sets which in turn contain subfolders for the different cities. For the purpose of this example we don't care about distinction between cities, so the following script scans every subdirectory gathering a list of paths for all the different images and masks and returning four list, namely training and validation sets of images and the corresponding masks.

# %%
import os

# This directory variables are set to the locations of masks and images in the 
# Cityscapes dataset locations.
dir_msk = '/content/gtFine'
dir_img = '/content/leftImg8bit'

def gatherPaths(dir_img, dir_msk):
    """ Recursively gather mask files under path dir_msk.
    Then build list of corresponding image paths in the same
    order."""
    msk_files = []
    img_files = []
    for i, r in enumerate(os.walk(dir_msk)):
        if i==0:
            towns = r[1]
        else:
            town = towns[i-1]
            files = r[2]
            for file in files:
                if 'labelIds' in file:
                    msk_files.append(
                        os.path.join(
                            dir_msk,
                            town,
                            file
                        )
                    )
                    img_files.append(
                        os.path.join(
                            dir_img,
                            town,
                            file.split('_gtFine_')[0]
                        ) 
                        + '_leftImg8bit.png'
                    )
    return img_files, msk_files

dir_img_train = os.path.join(dir_img, 'train')
dir_msk_train = os.path.join(dir_msk, 'train')

input_train_paths, target_train_paths = gatherPaths(dir_img_train, dir_msk_train) 

dir_img_val = os.path.join(dir_img, 'val')
dir_msk_val = os.path.join(dir_msk, 'val')

input_val_paths, target_val_paths = gatherPaths(dir_img_val, dir_msk_val)

# %% [markdown]
# ## Data generation

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import PIL

class CityScapesSegData(keras.utils.Sequence):
    """Helper to iterate over the data (as Numpy arrays)."""

    def __init__(self, batch_size, num_classes, img_size, input_img_paths, target_img_paths):
        self.batch_size = batch_size
        self.num_classes = num_classes
        self.img_size = img_size
        self.mask_size = img_size
        self.input_img_paths = input_img_paths
        self.target_img_paths = target_img_paths

    def __len__(self):
        return len(self.target_img_paths) // self.batch_size

    def __getitem__(self, idx):
        """Returns tuple (input, target) corresponding to batch #idx."""
        i = idx * self.batch_size
        batch_input_img_paths = self.input_img_paths[i : i + self.batch_size]
        batch_target_img_paths = self.target_img_paths[i : i + self.batch_size]
        x = np.zeros((batch_size,) + self.img_size + (3,), dtype="float32")
        y = np.zeros((batch_size,) + self.img_size + (1,), dtype="uint8")
        for j, (path_img, path_msk) in enumerate(zip(batch_input_img_paths, batch_target_img_paths)):
            img = load_img(path_img, target_size=self.img_size)
            x[j] = img
            msk = load_img(path_msk, target_size=self.mask_size, color_mode="grayscale")
            msk = np.expand_dims(msk, 2)
            y[j] = msk.astype('uint8')

        y = np.where(y==26, 1, 0)
        return x, y


# Instantiate data generators for each split

train_gen = CityScapesSegData(
    batch_size,
    num_classes,
    img_size,
    input_train_paths, 
    target_train_paths, 
)

val_gen = CityScapesSegData(
    batch_size, 
    num_classes, 
    img_size, 
    input_val_paths, 
    target_val_paths, 
)

# %% [markdown]
# ## Train the model

# %%
# Compile model for training
from tensorflow.keras import optimizers
from tensorflow.keras.metrics import CategoricalCrossentropy
import numpy as np

model.compile(
    optimizer=optimizers.RMSprop(lr=1e-5, momentum = 0.9), 
    loss="sparse_categorical_crossentropy", 
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "/content/U-Net-Xception_Segmentation.h5",
        monitor = 'val_loss',
        save_best_only=True,
        ),
    #keras.callbacks.EarlyStopping(
    #    monitor = 'val_loss',
    #   patience = 50,
    #)
]

# Train the model, doing validation at the end of each epoch.
history = model.fit(train_gen, epochs=epochs, validation_data=val_gen, callbacks=callbacks)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 333s 4s/step - loss: 0.3747 - val_loss: 0.4578
# Epoch 2/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.1322 - val_loss: 0.5882
# Epoch 3/100
# 92/92 [==============================] - 331s 4s/step - loss: 0.1066 - val_loss: 0.6835
# Epoch 4/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0927 - val_loss: 0.6807
# Epoch 5/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0862 - val_loss: 0.6122
# Epoch 6/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0797 - val_loss: 0.3610
# Epoch 7/100
# 92/92 [==============================] - 333s 4s/step - loss: 0.0722 - val_loss: 0.2042
# Epoch 8/100
# 92/92 [==============================] - 331s 4s/step - loss: 0.0666 - val_loss: 0.1562
# Epoch 9/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0619 - val_loss: 0.1200
# Epoch 10/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0579 - val_loss: 0.1044
# Epoch 11/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0535 - val_loss: 0.0977
# Epoch 12/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0514 - val_loss: 0.1031
# Epoch 13/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0476 - val_loss: 0.1369
# Epoch 14/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0452 - val_loss: 0.1381
# Epoch 15/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0425 - val_loss: 0.1120
# Epoch 16/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0416 - val_loss: 0.1088
# Epoch 17/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0395 - val_loss: 0.1197
# Epoch 18/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0380 - val_loss: 0.1215
# Epoch 19/100
# 92/92 [==============================] - 326s 4s/step - loss: 0.0361 - val_loss: 0.1462
# Epoch 20/100
# 92/92 [==============================] - 325s 4s/step - loss: 0.0347 - val_loss: 0.1213
# Epoch 21/100
# 92/92 [==============================] - 325s 4s/step - loss: 0.0343 - val_loss: 0.1268
# Epoch 22/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0327 - val_loss: 0.1204
# Epoch 23/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0318 - val_loss: 0.1240
# Epoch 24/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0308 - val_loss: 0.1286
# Epoch 25/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0306 - val_loss: 0.1293
# Epoch 26/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0300 - val_loss: 0.1371
# Epoch 27/100
# 92/92 [==============================] - 327s 4s/step - loss: 0.0297 - val_loss: 0.1279
# Epoch 28/100
# 92/92 [==============================] - 327s 4s/step - loss: 0.0283 - val_loss: 0.1280
# Epoch 29/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0278 - val_loss: 0.1340
# Epoch 30/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0272 - val_loss: 0.1410
# Epoch 31/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0270 - val_loss: 0.1422
# Epoch 32/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0265 - val_loss: 0.1352
# Epoch 33/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0262 - val_loss: 0.1402
# Epoch 34/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0254 - val_loss: 0.1431
# Epoch 35/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0257 - val_loss: 0.1320
# Epoch 36/100
# 92/92 [==============================] - 327s 4s/step - loss: 0.0251 - val_loss: 0.1407
# Epoch 37/100
# 92/92 [==============================] - 331s 4s/step - loss: 0.0250 - val_loss: 0.1505
# Epoch 38/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0248 - val_loss: 0.1366
# Epoch 39/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0244 - val_loss: 0.1392
# Epoch 40/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0238 - val_loss: 0.1445
# Epoch 41/100
# 92/92 [==============================] - 331s 4s/step - loss: 0.0236 - val_loss: 0.1417
# Epoch 42/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0229 - val_loss: 0.1583
# Epoch 43/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0227 - val_loss: 0.1468
# Epoch 44/100
# 92/92 [==============================] - 331s 4s/step - loss: 0.0228 - val_loss: 0.1646
# Epoch 45/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0226 - val_loss: 0.1468
# Epoch 46/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0224 - val_loss: 0.1451
# Epoch 47/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0218 - val_loss: 0.1518
# Epoch 48/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0211 - val_loss: 0.1560
# Epoch 49/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0206 - val_loss: 0.1505
# Epoch 50/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0203 - val_loss: 0.1679
# Epoch 51/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0201 - val_loss: 0.1589
# Epoch 52/100
# 92/92 [==============================] - 327s 4s/step - loss: 0.0200 - val_loss: 0.1622
# Epoch 53/100
# 92/92 [==============================] - 327s 4s/step - loss: 0.0199 - val_loss: 0.1640
# Epoch 54/100
# 92/92 [==============================] - 327s 4s/step - loss: 0.0195 - val_loss: 0.1596
# Epoch 55/100
# 92/92 [==============================] - 328s 4s/step - loss: 0.0192 - val_loss: 0.1639
# Epoch 56/100
# 92/92 [==============================] - 329s 4s/step - loss: 0.0193 - val_loss: 0.1640
# Epoch 57/100
# 92/92 [==============================] - 330s 4s/step - loss: 0.0195 - val_loss: 0.1676
# Epoch 58/100
# 92/92 [==============================] - 338s 4s/step - loss: 0.0195 - val_loss: 0.1676
# Epoch 59/100
# 92/92 [==============================] - 342s 4s/step - loss: 0.0190 - val_loss: 0.1587
# Epoch 60/100
# 31/92 [=========>....................] - ETA: 3:07 - loss: 0.0182
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-bba56e00e5f2> in <module>()
#      22
#      23 # Train the model, doing validation at the end of each epoch.
# ---> 24 history = model.fit(train_gen, epochs=epochs, validation_data=val_gen, callbacks=callbacks)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualise predictions on a few example images

# %%
import matplotlib.pyplot as plt
from imgaug import SegmentationMapOnImage

test_dir = '/content/leftImg8bit/test/berlin/'
jpg_pathlist = os.listdir(test_dir)
jpg_pathlist = [os.path.join(test_dir,x) for x in jpg_pathlist if '.jpg' in x or '.jpeg' in x or '.png' in x]

def showImgMsk(path, model):
  img = load_img(path, target_size = (160,160), color_mode='rgb')
  img = img_to_array(img, data_format='channels_last' ).astype('uint8')
  plt.figure(figsize=(12,36))
  plt.subplot(131)
  plt.imshow(img)
  img_batch = np.expand_dims(img, axis=0)
  pred_categorical = model.predict(img_batch)
  pred = np.argmax(pred_categorical, axis=3)
  plt.subplot(132)
  plt.imshow(pred[0])
  segmap = SegmentationMapOnImage(pred_categorical[0], shape=img.shape)
  segmap = segmap.draw_on_image(img)
  plt.subplot(133)
  plt.imshow(segmap)

for path in jpg_pathlist:
  showImgMsk(path,model)

# %%
jpg_pathlist
# Out:
# ['berlin_000418_000019_leftImg8bit.png',
#  'berlin_000375_000019_leftImg8bit.png',
#  'berlin_000206_000019_leftImg8bit.png',
#  'berlin_000230_000019_leftImg8bit.png',
#  'berlin_000033_000019_leftImg8bit.png',
#  'berlin_000518_000019_leftImg8bit.png',
#  'berlin_000401_000019_leftImg8bit.png',
#  'berlin_000451_000019_leftImg8bit.png',
#  'berlin_000022_000019_leftImg8bit.png',
#  'berlin_000093_000019_leftImg8bit.png',
#  'berlin_000476_000019_leftImg8bit.png',
#  'berlin_000326_000019_leftImg8bit.png',
#  'berlin_000071_000019_leftImg8bit.png',
#  'berlin_000056_000019_leftImg8bit.png',
#  'berlin_000461_000019_leftImg8bit.png',
#  'berlin_000410_000019_leftImg8bit.png',
#  'berlin_000507_000019_leftImg8bit.png',
#  'berlin_000013_000019_leftImg8bit.png',
#  'berlin_000049_000019_leftImg8bit.png',
#  'berlin_000124_000019_leftImg8bit.png',
#  'berlin_000284_000019_leftImg8bit.png',
#  'berlin_000542_000019_leftImg8bit.png',
#  'berlin_000038_000019_leftImg8bit.png',
#  'berlin_000062_000019_leftImg8bit.png',
#  'berlin_000514_000019_leftImg8bit.png',
#  'berlin_000290_000019_leftImg8bit.png',
#  'berlin_000310_000019_leftImg8bit.png',
#  'berlin_000521_000019_leftImg8bit.png',
#  'berlin_000535_000019_leftImg8bit.png',
#  'berlin_000219_000019_leftImg8bit.png',
#  'berlin_000247_000019_leftImg8bit.png',
#  'berlin_000169_000019_leftImg8bit.png',
#  'berlin_000534_000019_leftImg8bit.png',
#  'berlin_000174_000019_leftImg8bit.png',
#  'berlin_000434_000019_leftImg8bit.png',
#  'berlin_000501_000019_leftImg8bit.png',
#  'berlin_000511_000019_leftImg8bit.png',
#  'berlin_000419_000019_leftImg8bit.png',
#  'berlin_000196_000019_leftImg8bit.png',
#  'berlin_000394_000019_leftImg8bit.png',
#  'berlin_000422_000019_leftImg8bit.png',
#  'berlin_000041_000019_leftImg8bit.png',
#  'berlin_000444_000019_leftImg8bit.png',
#  'berlin_000098_000019_leftImg8bit.png',
#  'berlin_000346_000019_leftImg8bit.png',
#  'berlin_000262_000019_leftImg8bit.png',
#  'berlin_000374_000019_leftImg8bit.png',
#  'berlin_000485_000019_leftImg8bit.png',
#  'berlin_000255_000019_leftImg8bit.png',
#  'berlin_000536_000019_leftImg8bit.png',
#  'berlin_000199_000019_leftImg8bit.png',
#  'berlin_000312_000019_leftImg8bit.png',
#  'berlin_000504_000019_leftImg8bit.png',
#  'berlin_000459_000019_leftImg8bit.png',
#  'berlin_000189_000019_leftImg8bit.png',
#  'berlin_000204_000019_leftImg8bit.png',
#  'berlin_000466_000019_leftImg8bit.png',
#  'berlin_000252_000019_leftImg8bit.png',
#  'berlin_000277_000019_leftImg8bit.png',
#  'berlin_000193_000019_leftImg8bit.png',
#  'berlin_000463_000019_leftImg8bit.png',
#  'berlin_000226_000019_leftImg8bit.png',
#  'berlin_000381_000019_leftImg8bit.png',
#  'berlin_000280_000019_leftImg8bit.png',
#  'berlin_000272_000019_leftImg8bit.png',
#  'berlin_000268_000019_leftImg8bit.png',
#  'berlin_000490_000019_leftImg8bit.png',
#  'berlin_000197_000019_leftImg8bit.png',
#  'berlin_000254_000019_leftImg8bit.png',
#  'berlin_000359_000019_leftImg8bit.png',
#  'berlin_000183_000019_leftImg8bit.png',
#  'berlin_000433_000019_leftImg8bit.png',
#  'berlin_000004_000019_leftImg8bit.png',
#  'berlin_000106_000019_leftImg8bit.png',
#  'berlin_000048_000019_leftImg8bit.png',
#  'berlin_000110_000019_leftImg8bit.png',
#  'berlin_000342_000019_leftImg8bit.png',
#  'berlin_000267_000019_leftImg8bit.png',
#  'berlin_000085_000019_leftImg8bit.png',
#  'berlin_000008_000019_leftImg8bit.png',
#  'berlin_000032_000019_leftImg8bit.png',
#  'berlin_000300_000019_leftImg8bit.png',
#  'berlin_000180_000019_leftImg8bit.png',
#  'berlin_000320_000019_leftImg8bit.png',
#  'berlin_000386_000019_leftImg8bit.png',
#  'berlin_000454_000019_leftImg8bit.png',
#  'berlin_000371_000019_leftImg8bit.png',
#  'berlin_000317_000019_leftImg8bit.png',
#  'berlin_000436_000019_leftImg8bit.png',
#  'berlin_000481_000019_leftImg8bit.png',
#  'berlin_000248_000019_leftImg8bit.png',
#  'berlin_000131_000019_leftImg8bit.png',
#  'berlin_000221_000019_leftImg8bit.png',
#  'berlin_000244_000019_leftImg8bit.png',
#  'berlin_000360_000019_leftImg8bit.png',
#  'berlin_000366_000019_leftImg8bit.png',
#  'berlin_000478_000019_leftImg8bit.png',
#  'berlin_000127_000019_leftImg8bit.png',
#  'berlin_000132_000019_leftImg8bit.png',
#  'berlin_000054_000019_leftImg8bit.png',
#  'berlin_000020_000019_leftImg8bit.png',
#  'berlin_000297_000019_leftImg8bit.png',
#  'berlin_000191_000019_leftImg8bit.png',
#  'berlin_000322_000019_leftImg8bit.png',
#  'berlin_000497_000019_leftImg8bit.png',
#  'berlin_000533_000019_leftImg8bit.png',
#  'berlin_000319_000019_leftImg8bit.png',
#  'berlin_000187_000019_leftImg8bit.png',
#  'berlin_000515_000019_leftImg8bit.png',
#  'berlin_000522_000019_leftImg8bit.png',
#  'berlin_000147_000019_leftImg8bit.png',
#  'berlin_000194_000019_leftImg8bit.png',
#  'berlin_000345_000019_leftImg8bit.png',
#  'berlin_000465_000019_leftImg8bit.png',
#  'berlin_000092_000019_leftImg8bit.png',
#  'berlin_000449_000019_leftImg8bit.png',
#  'berlin_000355_000019_leftImg8bit.png',
#  'berlin_000324_000019_leftImg8bit.png',
#  'berlin_000045_000019_leftImg8bit.png',
#  'berlin_000097_000019_leftImg8bit.png',
#  'berlin_000482_000019_leftImg8bit.png',
#  'berlin_000007_000019_leftImg8bit.png',
#  'berlin_000431_000019_leftImg8bit.png',
#  'berlin_000099_000019_leftImg8bit.png',
#  'berlin_000323_000019_leftImg8bit.png',
#  'berlin_000258_000019_leftImg8bit.png',
#  'berlin_000040_000019_leftImg8bit.png',
#  'berlin_000437_000019_leftImg8bit.png',
#  'berlin_000442_000019_leftImg8bit.png',
#  'berlin_000236_000019_leftImg8bit.png',
#  'berlin_000362_000019_leftImg8bit.png',
#  'berlin_000216_000019_leftImg8bit.png',
#  'berlin_000154_000019_leftImg8bit.png',
#  'berlin_000526_000019_leftImg8bit.png',
#  'berlin_000279_000019_leftImg8bit.png',
#  'berlin_000249_000019_leftImg8bit.png',
#  'berlin_000298_000019_leftImg8bit.png',
#  'berlin_000067_000019_leftImg8bit.png',
#  'berlin_000104_000019_leftImg8bit.png',
#  'berlin_000330_000019_leftImg8bit.png',
#  'berlin_000318_000019_leftImg8bit.png',
#  'berlin_000391_000019_leftImg8bit.png',
#  'berlin_000117_000019_leftImg8bit.png',
#  'berlin_000105_000019_leftImg8bit.png',
#  'berlin_000429_000019_leftImg8bit.png',
#  'berlin_000113_000019_leftImg8bit.png',
#  'berlin_000399_000019_leftImg8bit.png',
#  'berlin_000037_000019_leftImg8bit.png',
#  'berlin_000164_000019_leftImg8bit.png',
#  'berlin_000168_000019_leftImg8bit.png',
#  'berlin_000393_000019_leftImg8bit.png',
#  'berlin_000250_000019_leftImg8bit.png',
#  'berlin_000210_000019_leftImg8bit.png',
#  'berlin_000469_000019_leftImg8bit.png',
#  'berlin_000055_000019_leftImg8bit.png',
#  'berlin_000162_000019_leftImg8bit.png',
#  'berlin_000395_000019_leftImg8bit.png',
#  'berlin_000246_000019_leftImg8bit.png',
#  'berlin_000153_000019_leftImg8bit.png',
#  'berlin_000529_000019_leftImg8bit.png',
#  'berlin_000358_000019_leftImg8bit.png',
#  'berlin_000523_000019_leftImg8bit.png',
#  'berlin_000103_000019_leftImg8bit.png',
#  'berlin_000165_000019_leftImg8bit.png',
#  'berlin_000370_000019_leftImg8bit.png',
#  'berlin_000467_000019_leftImg8bit.png',
#  'berlin_000208_000019_leftImg8bit.png',
#  'berlin_000520_000019_leftImg8bit.png',
#  'berlin_000011_000019_leftImg8bit.png',
#  'berlin_000356_000019_leftImg8bit.png',
#  'berlin_000075_000019_leftImg8bit.png',
#  'berlin_000291_000019_leftImg8bit.png',
#  'berlin_000380_000019_leftImg8bit.png',
#  'berlin_000477_000019_leftImg8bit.png',
#  'berlin_000334_000019_leftImg8bit.png',
#  'berlin_000464_000019_leftImg8bit.png',
#  'berlin_000470_000019_leftImg8bit.png',
#  'berlin_000030_000019_leftImg8bit.png',
#  'berlin_000350_000019_leftImg8bit.png',
#  'berlin_000192_000019_leftImg8bit.png',
#  'berlin_000351_000019_leftImg8bit.png',
#  'berlin_000271_000019_leftImg8bit.png',
#  'berlin_000425_000019_leftImg8bit.png',
#  'berlin_000306_000019_leftImg8bit.png',
#  'berlin_000120_000019_leftImg8bit.png',
#  'berlin_000445_000019_leftImg8bit.png',
#  'berlin_000188_000019_leftImg8bit.png',
#  'berlin_000128_000019_leftImg8bit.png',
#  'berlin_000006_000019_leftImg8bit.png',
#  'berlin_000426_000019_leftImg8bit.png',
#  'berlin_000435_000019_leftImg8bit.png',
#  'berlin_000142_000019_leftImg8bit.png',
#  'berlin_000299_000019_leftImg8bit.png',
#  'berlin_000096_000019_leftImg8bit.png',
#  'berlin_000309_000019_leftImg8bit.png',
#  'berlin_000003_000019_leftImg8bit.png',
#  'berlin_000537_000019_leftImg8bit.png',
#  'berlin_000276_000019_leftImg8bit.png',
#  'berlin_000102_000019_leftImg8bit.png',
#  'berlin_000223_000019_leftImg8bit.png',
#  'berlin_000403_000019_leftImg8bit.png',
#  'berlin_000443_000019_leftImg8bit.png',
#  'berlin_000087_000019_leftImg8bit.png',
#  'berlin_000157_000019_leftImg8bit.png',
#  'berlin_000220_000019_leftImg8bit.png',
#  'berlin_000489_000019_leftImg8bit.png',
#  'berlin_000353_000019_leftImg8bit.png',
#  'berlin_000413_000019_leftImg8bit.png',
#  'berlin_000385_000019_leftImg8bit.png',
#  'berlin_000245_000019_leftImg8bit.png',
#  'berlin_000212_000019_leftImg8bit.png',
#  'berlin_000144_000019_leftImg8bit.png',
#  'berlin_000237_000019_leftImg8bit.png',
#  'berlin_000338_000019_leftImg8bit.png',
#  'berlin_000148_000019_leftImg8bit.png',
#  'berlin_000078_000019_leftImg8bit.png',
#  'berlin_000379_000019_leftImg8bit.png',
#  'berlin_000070_000019_leftImg8bit.png',
#  'berlin_000090_000019_leftImg8bit.png',
#  'berlin_000125_000019_leftImg8bit.png',
#  'berlin_000000_000019_leftImg8bit.png',
#  'berlin_000261_000019_leftImg8bit.png',
#  'berlin_000336_000019_leftImg8bit.png',
#  'berlin_000480_000019_leftImg8bit.png',
#  'berlin_000058_000019_leftImg8bit.png',
#  'berlin_000528_000019_leftImg8bit.png',
#  'berlin_000084_000019_leftImg8bit.png',
#  'berlin_000389_000019_leftImg8bit.png',
#  'berlin_000095_000019_leftImg8bit.png',
#  'berlin_000414_000019_leftImg8bit.png',
#  'berlin_000073_000019_leftImg8bit.png',
#  'berlin_000031_000019_leftImg8bit.png',
#  'berlin_000079_000019_leftImg8bit.png',
#  'berlin_000066_000019_leftImg8bit.png',
#  'berlin_000065_000019_leftImg8bit.png',
#  'berlin_000347_000019_leftImg8bit.png',
#  'berlin_000225_000019_leftImg8bit.png',
#  'berlin_000296_000019_leftImg8bit.png',
#  'berlin_000491_000019_leftImg8bit.png',
#  'berlin_000161_000019_leftImg8bit.png',
#  'berlin_000453_000019_leftImg8bit.png',
#  'berlin_000388_000019_leftImg8bit.png',
#  'berlin_000178_000019_leftImg8bit.png',
#  'berlin_000215_000019_leftImg8bit.png',
#  'berlin_000305_000019_leftImg8bit.png',
#  'berlin_000151_000019_leftImg8bit.png',
#  'berlin_000541_000019_leftImg8bit.png',
#  'berlin_000118_000019_leftImg8bit.png',
#  'berlin_000158_000019_leftImg8bit.png',
#  'berlin_000015_000019_leftImg8bit.png',
#  'berlin_000421_000019_leftImg8bit.png',
#  'berlin_000137_000019_leftImg8bit.png',
#  'berlin_000505_000019_leftImg8bit.png',
#  'berlin_000407_000019_leftImg8bit.png',
#  'berlin_000232_000019_leftImg8bit.png',
#  'berlin_000140_000019_leftImg8bit.png',
#  'berlin_000455_000019_leftImg8bit.png',
#  'berlin_000200_000019_leftImg8bit.png',
#  'berlin_000502_000019_leftImg8bit.png',
#  'berlin_000138_000019_leftImg8bit.png',
#  'berlin_000089_000019_leftImg8bit.png',
#  'berlin_000352_000019_leftImg8bit.png',
#  'berlin_000417_000019_leftImg8bit.png',
#  'berlin_000021_000019_leftImg8bit.png',
#  'berlin_000175_000019_leftImg8bit.png',
#  'berlin_000496_000019_leftImg8bit.png',
#  'berlin_000238_000019_leftImg8bit.png',
#  'berlin_000170_000019_leftImg8bit.png',
#  'berlin_000438_000019_leftImg8bit.png',
#  'berlin_000474_000019_leftImg8bit.png',
#  'berlin_000331_000019_leftImg8bit.png',
#  'berlin_000077_000019_leftImg8bit.png',
#  'berlin_000083_000019_leftImg8bit.png',
#  'berlin_000289_000019_leftImg8bit.png',
#  'berlin_000500_000019_leftImg8bit.png',
#  'berlin_000053_000019_leftImg8bit.png',
#  'berlin_000119_000019_leftImg8bit.png',
#  'berlin_000116_000019_leftImg8bit.png',
#  'berlin_000047_000019_leftImg8bit.png',
#  'berlin_000439_000019_leftImg8bit.png',
#  'berlin_000150_000019_leftImg8bit.png',
#  'berlin_000186_000019_leftImg8bit.png',
#  'berlin_000416_000019_leftImg8bit.png',
#  'berlin_000348_000019_leftImg8bit.png',
#  'berlin_000492_000019_leftImg8bit.png',
#  'berlin_000446_000019_leftImg8bit.png',
#  'berlin_000155_000019_leftImg8bit.png',
#  'berlin_000468_000019_leftImg8bit.png',
#  'berlin_000510_000019_leftImg8bit.png',
#  'berlin_000378_000019_leftImg8bit.png',
#  'berlin_000286_000019_leftImg8bit.png',
#  'berlin_000282_000019_leftImg8bit.png',
#  'berlin_000091_000019_leftImg8bit.png',
#  'berlin_000498_000019_leftImg8bit.png',
#  'berlin_000082_000019_leftImg8bit.png',
#  'berlin_000472_000019_leftImg8bit.png',
#  'berlin_000473_000019_leftImg8bit.png',
#  'berlin_000063_000019_leftImg8bit.png',
#  'berlin_000285_000019_leftImg8bit.png',
#  'berlin_000052_000019_leftImg8bit.png',
#  'berlin_000294_000019_leftImg8bit.png',
#  'berlin_000512_000019_leftImg8bit.png',
#  'berlin_000028_000019_leftImg8bit.png',
#  'berlin_000524_000019_leftImg8bit.png',
#  'berlin_000122_000019_leftImg8bit.png',
#  'berlin_000440_000019_leftImg8bit.png',
#  'berlin_000543_000019_leftImg8bit.png',
#  'berlin_000234_000019_leftImg8bit.png',
#  'berlin_000217_000019_leftImg8bit.png',
#  'berlin_000167_000019_leftImg8bit.png',
#  'berlin_000457_000019_leftImg8bit.png',
#  'berlin_000111_000019_leftImg8bit.png',
#  'berlin_000341_000019_leftImg8bit.png',
#  'berlin_000107_000019_leftImg8bit.png',
#  'berlin_000519_000019_leftImg8bit.png',
#  'berlin_000368_000019_leftImg8bit.png',
#  'berlin_000112_000019_leftImg8bit.png',
#  'berlin_000176_000019_leftImg8bit.png',
#  'berlin_000182_000019_leftImg8bit.png',
#  'berlin_000452_000019_leftImg8bit.png',
#  'berlin_000159_000019_leftImg8bit.png',
#  'berlin_000242_000019_leftImg8bit.png',
#  'berlin_000377_000019_leftImg8bit.png',
#  'berlin_000516_000019_leftImg8bit.png',
#  'berlin_000042_000019_leftImg8bit.png',
#  'berlin_000423_000019_leftImg8bit.png',
#  'berlin_000302_000019_leftImg8bit.png',
#  'berlin_000369_000019_leftImg8bit.png',
#  'berlin_000301_000019_leftImg8bit.png',
#  'berlin_000404_000019_leftImg8bit.png',
#  'berlin_000447_000019_leftImg8bit.png',
#  'berlin_000126_000019_leftImg8bit.png',
#  'berlin_000114_000019_leftImg8bit.png',
#  'berlin_000441_000019_leftImg8bit.png',
#  'berlin_000372_000019_leftImg8bit.png',
#  'berlin_000024_000019_leftImg8bit.png',
#  'berlin_000207_000019_leftImg8bit.png',
#  'berlin_000213_000019_leftImg8bit.png',
#  'berlin_000017_000019_leftImg8bit.png',
#  'berlin_000253_000019_leftImg8bit.png',
#  'berlin_000460_000019_leftImg8bit.png',
#  'berlin_000025_000019_leftImg8bit.png',
#  'berlin_000539_000019_leftImg8bit.png',
#  'berlin_000405_000019_leftImg8bit.png',
#  'berlin_000408_000019_leftImg8bit.png',
#  'berlin_000343_000019_leftImg8bit.png',
#  'berlin_000012_000019_leftImg8bit.png',
#  'berlin_000072_000019_leftImg8bit.png',
#  'berlin_000123_000019_leftImg8bit.png',
#  'berlin_000288_000019_leftImg8bit.png',
#  'berlin_000043_000019_leftImg8bit.png',
#  'berlin_000115_000019_leftImg8bit.png',
#  'berlin_000383_000019_leftImg8bit.png',
#  'berlin_000227_000019_leftImg8bit.png',
#  'berlin_000185_000019_leftImg8bit.png',
#  'berlin_000134_000019_leftImg8bit.png',
#  'berlin_000387_000019_leftImg8bit.png',
#  'berlin_000181_000019_leftImg8bit.png',
#  'berlin_000146_000019_leftImg8bit.png',
#  'berlin_000487_000019_leftImg8bit.png',
#  'berlin_000275_000019_leftImg8bit.png',
#  'berlin_000179_000019_leftImg8bit.png',
#  'berlin_000133_000019_leftImg8bit.png',
#  'berlin_000243_000019_leftImg8bit.png',
#  'berlin_000068_000019_leftImg8bit.png',
#  'berlin_000074_000019_leftImg8bit.png',
#  'berlin_000145_000019_leftImg8bit.png',
#  'berlin_000051_000019_leftImg8bit.png',
#  'berlin_000172_000019_leftImg8bit.png',
#  'berlin_000057_000019_leftImg8bit.png',
#  'berlin_000538_000019_leftImg8bit.png',
#  'berlin_000293_000019_leftImg8bit.png',
#  'berlin_000214_000019_leftImg8bit.png',
#  'berlin_000409_000019_leftImg8bit.png',
#  'berlin_000373_000019_leftImg8bit.png',
#  'berlin_000430_000019_leftImg8bit.png',
#  'berlin_000160_000019_leftImg8bit.png',
#  'berlin_000029_000019_leftImg8bit.png',
#  'berlin_000273_000019_leftImg8bit.png',
#  'berlin_000211_000019_leftImg8bit.png',
#  'berlin_000392_000019_leftImg8bit.png',
#  'berlin_000152_000019_leftImg8bit.png',
#  'berlin_000108_000019_leftImg8bit.png',
#  'berlin_000475_000019_leftImg8bit.png',
#  'berlin_000266_000019_leftImg8bit.png',
#  'berlin_000035_000019_leftImg8bit.png',
#  'berlin_000026_000019_leftImg8bit.png',
#  'berlin_000339_000019_leftImg8bit.png',
#  'berlin_000264_000019_leftImg8bit.png',
#  'berlin_000494_000019_leftImg8bit.png',
#  'berlin_000424_000019_leftImg8bit.png',
#  'berlin_000486_000019_leftImg8bit.png',
#  'berlin_000166_000019_leftImg8bit.png',
#  'berlin_000240_000019_leftImg8bit.png',
#  'berlin_000257_000019_leftImg8bit.png',
#  'berlin_000530_000019_leftImg8bit.png',
#  'berlin_000278_000019_leftImg8bit.png',
#  'berlin_000427_000019_leftImg8bit.png',
#  'berlin_000036_000019_leftImg8bit.png',
#  'berlin_000503_000019_leftImg8bit.png',
#  'berlin_000376_000019_leftImg8bit.png',
#  'berlin_000402_000019_leftImg8bit.png',
#  'berlin_000412_000019_leftImg8bit.png',
#  'berlin_000506_000019_leftImg8bit.png',
#  'berlin_000471_000019_leftImg8bit.png',
#  'berlin_000019_000019_leftImg8bit.png',
#  'berlin_000390_000019_leftImg8bit.png',
#  'berlin_000069_000019_leftImg8bit.png',
#  'berlin_000367_000019_leftImg8bit.png',
#  'berlin_000313_000019_leftImg8bit.png',
#  'berlin_000349_000019_leftImg8bit.png',
#  'berlin_000005_000019_leftImg8bit.png',
#  'berlin_000525_000019_leftImg8bit.png',
#  'berlin_000141_000019_leftImg8bit.png',
#  'berlin_000361_000019_leftImg8bit.png',
#  'berlin_000307_000019_leftImg8bit.png',
#  'berlin_000044_000019_leftImg8bit.png',
#  'berlin_000039_000019_leftImg8bit.png',
#  'berlin_000205_000019_leftImg8bit.png',
#  'berlin_000101_000019_leftImg8bit.png',
#  'berlin_000363_000019_leftImg8bit.png',
#  'berlin_000149_000019_leftImg8bit.png',
#  'berlin_000488_000019_leftImg8bit.png',
#  'berlin_000295_000019_leftImg8bit.png',
#  'berlin_000315_000019_leftImg8bit.png',
#  'berlin_000382_000019_leftImg8bit.png',
#  'berlin_000088_000019_leftImg8bit.png',
#  'berlin_000420_000019_leftImg8bit.png',
#  'berlin_000222_000019_leftImg8bit.png',
#  'berlin_000337_000019_leftImg8bit.png',
#  'berlin_000094_000019_leftImg8bit.png',
#  'berlin_000335_000019_leftImg8bit.png',
#  'berlin_000269_000019_leftImg8bit.png',
#  'berlin_000287_000019_leftImg8bit.png',
#  'berlin_000260_000019_leftImg8bit.png',
#  'berlin_000241_000019_leftImg8bit.png',
#  'berlin_000400_000019_leftImg8bit.png',
#  'berlin_000513_000019_leftImg8bit.png',
#  'berlin_000316_000019_leftImg8bit.png',
#  'berlin_000100_000019_leftImg8bit.png',
#  'berlin_000027_000019_leftImg8bit.png',
#  'berlin_000129_000019_leftImg8bit.png',
#  'berlin_000406_000019_leftImg8bit.png',
#  'berlin_000023_000019_leftImg8bit.png',
#  'berlin_000321_000019_leftImg8bit.png',
#  'berlin_000195_000019_leftImg8bit.png',
#  'berlin_000173_000019_leftImg8bit.png',
#  'berlin_000239_000019_leftImg8bit.png',
#  'berlin_000308_000019_leftImg8bit.png',
#  'berlin_000010_000019_leftImg8bit.png',
#  'berlin_000344_000019_leftImg8bit.png',
#  'berlin_000228_000019_leftImg8bit.png',
#  'berlin_000415_000019_leftImg8bit.png',
#  'berlin_000076_000019_leftImg8bit.png',
#  'berlin_000130_000019_leftImg8bit.png',
#  'berlin_000532_000019_leftImg8bit.png',
#  'berlin_000034_000019_leftImg8bit.png',
#  'berlin_000061_000019_leftImg8bit.png',
#  'berlin_000328_000019_leftImg8bit.png',
#  'berlin_000270_000019_leftImg8bit.png',
#  'berlin_000292_000019_leftImg8bit.png',
#  'berlin_000059_000019_leftImg8bit.png',
#  'berlin_000327_000019_leftImg8bit.png',
#  'berlin_000139_000019_leftImg8bit.png',
#  'berlin_000509_000019_leftImg8bit.png',
#  'berlin_000448_000019_leftImg8bit.png',
#  'berlin_000479_000019_leftImg8bit.png',
#  'berlin_000014_000019_leftImg8bit.png',
#  'berlin_000340_000019_leftImg8bit.png',
#  'berlin_000508_000019_leftImg8bit.png',
#  'berlin_000190_000019_leftImg8bit.png',
#  'berlin_000109_000019_leftImg8bit.png',
#  'berlin_000263_000019_leftImg8bit.png',
#  'berlin_000493_000019_leftImg8bit.png',
#  'berlin_000450_000019_leftImg8bit.png',
#  'berlin_000332_000019_leftImg8bit.png',
#  'berlin_000231_000019_leftImg8bit.png',
#  'berlin_000304_000019_leftImg8bit.png',
#  'berlin_000060_000019_leftImg8bit.png',
#  'berlin_000483_000019_leftImg8bit.png',
#  'berlin_000121_000019_leftImg8bit.png',
#  'berlin_000540_000019_leftImg8bit.png',
#  'berlin_000001_000019_leftImg8bit.png',
#  'berlin_000218_000019_leftImg8bit.png',
#  'berlin_000265_000019_leftImg8bit.png',
#  'berlin_000016_000019_leftImg8bit.png',
#  'berlin_000365_000019_leftImg8bit.png',
#  'berlin_000086_000019_leftImg8bit.png',
#  'berlin_000397_000019_leftImg8bit.png',
#  'berlin_000046_000019_leftImg8bit.png',
#  'berlin_000143_000019_leftImg8bit.png',
#  'berlin_000364_000019_leftImg8bit.png',
#  'berlin_000201_000019_leftImg8bit.png',
#  'berlin_000233_000019_leftImg8bit.png',
#  'berlin_000283_000019_leftImg8bit.png',
#  'berlin_000531_000019_leftImg8bit.png',
#  'berlin_000495_000019_leftImg8bit.png',
#  'berlin_000311_000019_leftImg8bit.png',
#  'berlin_000333_000019_leftImg8bit.png',
#  'berlin_000064_000019_leftImg8bit.png',
#  'berlin_000303_000019_leftImg8bit.png',
#  'berlin_000281_000019_leftImg8bit.png',
#  'berlin_000224_000019_leftImg8bit.png',
#  'berlin_000136_000019_leftImg8bit.png',
#  'berlin_000135_000019_leftImg8bit.png',
#  'berlin_000396_000019_leftImg8bit.png',
#  'berlin_000203_000019_leftImg8bit.png',
#  'berlin_000229_000019_leftImg8bit.png',
#  'berlin_000184_000019_leftImg8bit.png',
#  'berlin_000080_000019_leftImg8bit.png',
#  'berlin_000398_000019_leftImg8bit.png',
#  'berlin_000357_000019_leftImg8bit.png',
#  'berlin_000428_000019_leftImg8bit.png',
#  'berlin_000462_000019_leftImg8bit.png',
#  'berlin_000458_000019_leftImg8bit.png',
#  'berlin_000456_000019_leftImg8bit.png',
#  'berlin_000325_000019_leftImg8bit.png',
#  'berlin_000209_000019_leftImg8bit.png',
#  'berlin_000499_000019_leftImg8bit.png',
#  'berlin_000384_000019_leftImg8bit.png',
#  'berlin_000484_000019_leftImg8bit.png',
#  'berlin_000527_000019_leftImg8bit.png',
#  'berlin_000171_000019_leftImg8bit.png',
#  'berlin_000177_000019_leftImg8bit.png',
#  'berlin_000517_000019_leftImg8bit.png',
#  'berlin_000411_000019_leftImg8bit.png',
#  'berlin_000235_000019_leftImg8bit.png',
#  'berlin_000329_000019_leftImg8bit.png',
#  'berlin_000081_000019_leftImg8bit.png',
#  'berlin_000198_000019_leftImg8bit.png',
#  'berlin_000354_000019_leftImg8bit.png',
#  'berlin_000314_000019_leftImg8bit.png',
#  'berlin_000163_000019_leftImg8bit.png',
#  'berlin_000251_000019_leftImg8bit.png',
#  'berlin_000018_000019_leftImg8bit.png',
#  'berlin_000009_000019_leftImg8bit.png',
#  'berlin_000256_000019_leftImg8bit.png',
#  'berlin_000274_000019_leftImg8bit.png',
#  'berlin_000432_000019_leftImg8bit.png',
#  'berlin_000156_000019_leftImg8bit.png',
#  'berlin_000202_000019_leftImg8bit.png',
#  'berlin_000259_000019_leftImg8bit.png',
#  'berlin_000002_000019_leftImg8bit.png',
#  'berlin_000050_000019_leftImg8bit.png']

# %% [markdown]
# ## Citations
#
# [1] M. Cordts, M. Omran, S. Ramos, T. Rehfeld, M. Enzweiler, R. Benenson, U. Franke, S. Roth, and B. Schiele, “The Cityscapes Dataset for Semantic Urban Scene Understanding,” in Proc. of the IEEE Conference on Computer Vision and Pattern Recognition (CVPR), 2016.
#
# [2] François Chollet, "Image segmentation with a U-Net-like architecture". The Keras Blog, Code Examples ([Link](https://keras.io/examples/vision/oxford_pets_image_segmentation/)).
